# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\User\Downloads\patient_health.csv"
df = pd.read_csv(file_path)

# %%
# Importing the libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.utils.class_weight import compute_sample_weight

# %% [markdown]
# EXPLORATORY ANALYSIS

# %%
# Preview the dataset
print(df.head())
# Out:
#    PatientID   Age Gender     Diagnosis AppointmentDate         Outcome  \
# 0          1  43.0      M        Asthma      01/01/2024  Did Not Attend
# 1          2  42.0      F      Diabetes      02/01/2024        Attended
# 2          3  57.0      M      Diabetes      03/01/2024        Attended
# 3          4  76.0      F  Hypertension      04/01/2024        Attended
# 4          5  63.0      F        Asthma      05/01/2024        Attended
#
#   GPPractice
# 0       C789
# 1       A123
# 2       D012
# 3       E345
# 4       C789

# %%
# information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PatientID        5000 non-null   int64
#  1   Age              4997 non-null   float64
#  2   Gender           4997 non-null   object
#  3   Diagnosis        4999 non-null   object
#  4   AppointmentDate  4998 non-null   object
#  5   Outcome          4998 non-null   object
#  6   GPPractice       4999 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 273.6+ KB

# %%
#Statistical Summary for Numeric Columns
print("\nStatistical Summary (Numeric Columns):")
print(df.describe())
# Out:
# Statistical Summary (Numeric Columns):
#          PatientID          Age
# count  4996.000000  4996.000000
# mean   2498.746998    53.328463
# std    1442.755174    20.758153
# min       1.000000    18.000000
# 25%    1249.750000    35.750000
# 50%    2498.500000    53.000000
# 75%    3747.250000    72.000000
# max    5000.000000    89.000000

# %%
#Unique Values in Categorical Columns
print("\nUnique Values in Categorical Columns:")
for col in df.select_dtypes(include='object').columns:
    print(f"{col}: {df[col].unique()}")
# Out:
# Unique Values in Categorical Columns:
# Gender: ['M' 'F']
# Diagnosis: ['Asthma' 'Diabetes' 'Hypertension' 'Unknown']
# Outcome: ['Did Not Attend' 'Attended' 'Attend' 'Didnotattend' 'Dna']
# GPPractice: ['C789' 'A123' 'D012' 'E345' 'B456']

# %%
#Age Distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], bins=30, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Outcome Distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Outcome', data=df, palette='Set2')
plt.title('Outcome Distribution (Attendance vs. No-Show)')
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.show()

# %%
#  Gender Distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=df, palette='Set1')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# DATA CLEANING

# %%
#Check for missing values
print("\nColumn-wise Missing Values:")
print(df.isnull().sum())
# Out:
# Column-wise Missing Values:
# PatientID          0
# Age                3
# Gender             3
# Diagnosis          1
# AppointmentDate    2
# Outcome            2
# GPPractice         1
# dtype: int64

# %%
#Check for Duplicate Records
duplicate_count = df.duplicated().sum()
print(f"\nNumber of Duplicate Rows: {duplicate_count}")
# Out:
# Number of Duplicate Rows: 0

# %%
#Data Type of AppointmentDate and Invalid Dates
try:
    # Convert 'AppointmentDate' to datetime format
    df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
    
    # Count invalid dates (will be NaT if conversion failed)
    invalid_dates = df['AppointmentDate'].isnull().sum()
    
    print(f"\nInvalid Appointment Dates: {invalid_dates}")
    
except Exception as e:
    print(f"Error parsing dates: {e}")
# Out:
# Invalid Appointment Dates: 2
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '31/01/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/02/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '31/03/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/04/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '31/05/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17 06 2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '31/07/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15 08 2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '31/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/09/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/10/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/10/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/10/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/10/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/10/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/10/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '31/07/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '27/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '30/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '31/08/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '14/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '16/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '18/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '19/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '21/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '23/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '25/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26/09/2026' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24 07 2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '26 01 2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/10/2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '28/01/2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '15/08/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22 05 2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '20 11 2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '29 11 2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '22 10 2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '17/06/2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '13 06 2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\402323046.py:4: UserWarning: Parsing '24 08 2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], errors='coerce')

# %%
#Visualize Missing Data
import matplotlib.pyplot as plt
import seaborn as sns

# Count missing values
missing_values = df.isnull().sum()

# Filter columns with missing values
missing_values = missing_values[missing_values > 0]

plt.figure(figsize=(8, 5))
sns.barplot(x=missing_values.index, y=missing_values.values, palette="mako")
plt.title('Count of Missing Values by Column')
plt.ylabel('Number of Missing Values')
plt.xlabel('Columns')
plt.xticks(rotation=45)
plt.show()

# %%
#  Check for Invalid Ages (e.g., negative values)
print("\nInvalid Age Entries:")
print(df[df['Age'] < 0])
# Out:
# Invalid Age Entries:
# Empty DataFrame
# Columns: [PatientID, Age, Gender, Diagnosis, AppointmentDate, Outcome, GPPractice]
# Index: []

# %%
#Handling Missing Data ###

# Check for missing values
print("Missing Values Before Cleaning:")
print(df.isnull().sum())

# Impute missing Age with median (reasonable for numerical data)
df['Age'].fillna(df['Age'].median(), inplace=True)

# Impute missing Gender with the mode (most frequent value)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# Replace missing Diagnosis with 'Unknown'
df['Diagnosis'].fillna('Unknown', inplace=True)

# Drop rows where critical information is missing (AppointmentDate, Outcome)
df.dropna(subset=['AppointmentDate', 'Outcome'], inplace=True)

# Impute missing GPPractice with the mode (most frequent value)
df['GPPractice'].fillna(df['GPPractice'].mode()[0], inplace=True)

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())
# Out:
# Missing Values Before Cleaning:
# PatientID          0
# Age                3
# Gender             3
# Diagnosis          1
# AppointmentDate    2
# Outcome            2
# GPPractice         1
# dtype: int64
#
# Missing Values After Cleaning:
# PatientID          0
# Age                0
# Gender             0
# Diagnosis          0
# AppointmentDate    0
# Outcome            0
# GPPractice         0
# dtype: int64

# %%
# Convert AppointmentDate to datetime format
df['AppointmentDate'] = pd.to_datetime(df['AppointmentDate'], format='%d/%m/%Y', errors='coerce')

# Drop rows with invalid AppointmentDate (those that couldn't be converted)
df.dropna(subset=['AppointmentDate'], inplace=True)

print("\nCheck for Invalid Dates (After Conversion):")
print(df['AppointmentDate'].isnull().sum())
# Out:
# Check for Invalid Dates (After Conversion):
# 0

# %%
#Standardize Categorical Fields ###

# Standardize Outcome (e.g., 'Did Not Attend' -> 'Did Not Attend')
df['Outcome'] = df['Outcome'].str.strip().str.title()

# Standardize Gender (e.g., 'Male', 'Female')
df['Gender'] = df['Gender'].str.strip().str.title()

# Verify cleaned Outcome and Gender
print("\nUnique Outcomes After Cleaning:", df['Outcome'].unique())
print("Unique Genders After Cleaning:", df['Gender'].unique())
# Out:
# Unique Outcomes After Cleaning: ['Did Not Attend' 'Attended' 'Attend' 'Didnotattend' 'Dna']
# Unique Genders After Cleaning: ['M' 'F']

# %%
#Handle Inconsistent Data (e.g., Negative Ages) ###

# Remove rows where Age is negative or unreasonable (e.g., >120)
df = df[(df['Age'] >= 0) & (df['Age'] <= 120)]

print("\nCheck for Invalid Ages (After Cleaning):")
print(df[df['Age'] < 0])
# Out:
# Check for Invalid Ages (After Cleaning):
# Empty DataFrame
# Columns: [PatientID, Age, Gender, Diagnosis, AppointmentDate, Outcome, GPPractice]
# Index: []

# %%
df_cleaned = df.copy()

# %%
 print(df_cleaned.head())
# Out:
#    PatientID   Age Gender     Diagnosis AppointmentDate         Outcome  \
# 0          1  43.0      M        Asthma      2024-01-01  Did Not Attend
# 1          2  42.0      F      Diabetes      2024-02-01        Attended
# 2          3  57.0      M      Diabetes      2024-03-01        Attended
# 3          4  76.0      F  Hypertension      2024-04-01        Attended
# 4          5  63.0      F        Asthma      2024-05-01        Attended
#
#   GPPractice
# 0       C789
# 1       A123
# 2       D012
# 3       E345
# 4       C789

# %%
## ---- PLOT 2: Box Plot by Outcome ----
plt.figure(figsize=(8, 5))
sns.boxplot(x='Outcome', y='Age', data=df_cleaned, palette='coolwarm')

plt.xlabel("Outcome", fontsize=12)
plt.ylabel("Age", fontsize=12)
plt.title("Box Plot of Age by Outcome", fontsize=14)

plt.show()

## ---- PLOT 3: Density Plot (KDE) by Outcome ----
# KDE Density Plot Fix
plt.figure(figsize=(10, 5))
sns.kdeplot(data=df, x='Age', hue='Outcome', fill=True, common_norm=False, palette='coolwarm', alpha=0.5)

plt.xlabel("Age", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("Age Density by Outcome", fontsize=14)
plt.legend(title="Outcome", labels=df['Outcome'].unique())  # Manually set legend

plt.show()

# %% [markdown]
# Descriptive Statistics and Insights

# %%
# Calculate the No-Show Rate (Assuming 'Outcome' column contains 'Attended' and 'Did Not Attend')
no_show_rate = df_cleaned.groupby('GPPractice')['Outcome'].apply(lambda x: (x == 'Did Not Attend').mean())

# Convert to percentage
no_show_rate *= 100  

# Display results
print("No-Show Rate by GP Practice:\n", no_show_rate)
# Calculate the rate for each outcome by GPPractice
attended_rate = df_cleaned.groupby('GPPractice')['Outcome'].apply(lambda x: (x == 'Attended').mean()) * 100
did_not_attend_rate = df_cleaned.groupby('GPPractice')['Outcome'].apply(lambda x: (x == 'Did Not Attend').mean()) * 100
attend_rate = df_cleaned.groupby('GPPractice')['Outcome'].apply(lambda x: (x == 'Attend').mean()) * 100
did_not_attend_alt_rate = df_cleaned.groupby('GPPractice')['Outcome'].apply(lambda x: (x == 'DidNotAttend').mean()) * 100
dna_rate = df_cleaned.groupby('GPPractice')['Outcome'].apply(lambda x: (x == 'DNA').mean()) * 100

# Display results
print("Attended Rate by GP Practice:\n", attended_rate)
print("\nDid Not Attend Rate by GP Practice:\n", did_not_attend_rate)
print("\nAttend Rate by GP Practice:\n", attend_rate)
print("\nDidNotAttend Rate by GP Practice:\n", did_not_attend_alt_rate)
print("\nDNA Rate by GP Practice:\n", dna_rate)
# Out:
# Attended Rate by GP Practice:
#  GPPractice
# A123    51.751752
# B456    45.253456
# C789    50.757576
# D012    41.521069
# E345    53.497537
# Name: Outcome, dtype: float64
#
# Did Not Attend Rate by GP Practice:
#  GPPractice
# A123    45.445445
# B456    53.087558
# C789    47.619048
# D012    57.245632
# E345    43.842365
# Name: Outcome, dtype: float64
#
# Attend Rate by GP Practice:
#  GPPractice
# A123    1.401401
# B456    0.552995
# C789    0.649351
# D012    0.308325
# E345    1.576355
# Name: Outcome, dtype: float64
#
# DidNotAttend Rate by GP Practice:
#  GPPractice
# A123    0.0
# B456    0.0
# C789    0.0
# D012    0.0
# E345    0.0
# Name: Outcome, dtype: float64
#
# DNA Rate by GP Practice:
#  GPPractice
# A123    0.0
# B456    0.0
# C789    0.0
# D012    0.0
# E345    0.0
# Name: Outcome, dtype: float64

# %%
# Combine into a single dataframe for plotting
outcome_rates = pd.DataFrame({
    'Attended': attended_rate,
    'Did Not Attend': did_not_attend_rate,
    'Attend': attend_rate,
    'DidNotAttend': did_not_attend_alt_rate,
    'DNA': dna_rate
})

# Plot the bar chart
outcome_rates.plot(kind='bar', figsize=(12, 6))
plt.title('Outcome Rate by GP Practice')
plt.ylabel('Rate (%)')
plt.xlabel('GP Practice')
plt.legend(title='Outcome')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Group by Diagnosis and calculate descriptive statistics for Age
age_distribution = df_cleaned.groupby('Diagnosis')['Age'].agg(
    Mean='mean', Median='median', Min='min', Max='max'
)

# Calculate age range
age_distribution['Range'] = age_distribution['Max'] - age_distribution['Min']

# Format results (optional)
age_distribution = age_distribution.round(2)  # Show two decimal places

# Display results
print("\n📊 Age Distribution by Diagnosis:")
print(age_distribution)
# Out:
# 📊 Age Distribution by Diagnosis:
#                Mean  Median   Min   Max  Range
# Diagnosis
# Asthma        51.69    50.0  18.0  89.0   71.0
# Diabetes      54.67    55.0  18.0  89.0   71.0
# Hypertension  53.67    54.0  18.0  89.0   71.0
# Unknown       26.00    26.0  26.0  26.0    0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(12, 6))

# Create histogram with multiple categories using 'hue'
sns.histplot(data=df_cleaned, x='Age', hue='Diagnosis', multiple='stack', bins=20, palette='coolwarm', kde=True)

# Labels and title
plt.xlabel("Age", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Age Distribution by Diagnosis (Histogram)", fontsize=14)

# Show the plot
plt.show()

# %%
# Count of Male and Female for each Diagnosis
gender_counts = df_cleaned.groupby(['Diagnosis', 'Gender']).size().unstack(fill_value=0)

# Convert counts to proportions
gender_proportion = gender_counts.div(gender_counts.sum(axis=1), axis=0) * 100  

# Display results
print("Proportion of Male and Female Patients by Diagnosis:\n", gender_proportion)
# Out:
# Proportion of Male and Female Patients by Diagnosis:
#  Gender                 F          M
# Diagnosis
# Asthma         48.321759  51.678241
# Diabetes       49.281196  50.718804
# Hypertension   57.264398  42.735602
# Unknown       100.000000   0.000000

# %%
import matplotlib.pyplot as plt

# Create pie charts for each diagnosis
for diagnosis in gender_proportion.index:
    plt.figure(figsize=(6, 6))  # Set figure size
    
    # Get data for the specific diagnosis
    labels = gender_proportion.columns  # Male, Female
    sizes = gender_proportion.loc[diagnosis]  # Corresponding proportions
    
    # Create pie chart
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['lightblue', 'pink'], startangle=140, wedgeprops={'edgecolor': 'black'})
    
    # Title
    plt.title(f"Gender Proportion for {diagnosis}", fontsize=14)
    
    # Show plot
    plt.show()

# %% [markdown]
# DATA CLEANING BEFORE PREDICTION

# %%
# Fix inconsistent labels and classify into "Missed" or "Attended"
df_cleaned['OutcomeClass'] = df_cleaned['Outcome'].replace({
    'attend': 'attended',
    'didnotattend': 'missed',
    'dna': 'missed',
    'did not attend': 'missed',
    'attended': 'attended'
})

#Drop invalid or missing values
df_clean = df_cleaned.dropna(subset=['OutcomeClass'])

# Create the binary target variable
df_clean['MissedAppointment'] =df_clean['OutcomeClass'].apply(lambda x: 1 if x == 'missed' else 0)

# Check the cleaned data
print(df_clean['OutcomeClass'].value_counts())
print(df_clean[['Outcome', 'OutcomeClass', 'MissedAppointment']].head())
# Out:
# missed      2527
# attended    2469
# Name: OutcomeClass, dtype: int64
#           Outcome OutcomeClass  MissedAppointment
# 0  did not attend       missed                  1
# 1        attended     attended                  0
# 2        attended     attended                  0
# 3        attended     attended                  0
# 4        attended     attended                  0

# %%
print(df_clean['Outcome'])
# Out:
# 0       did not attend
# 1             attended
# 2             attended
# 3             attended
# 4             attended
#              ...
# 4995          attended
# 4996          attended
# 4997    did not attend
# 4998          attended
# 4999    did not attend
# Name: Outcome, Length: 4996, dtype: object

# %%
print("\nUnique Outcomes After Cleaning:", df_cleaned['OutcomeClass'].unique())
# Out:
# Unique Outcomes After Cleaning: ['missed' 'attended']

# %%
#Select relevant features for the predictive model
model_df = df_clean[['Age', 'Diagnosis', 'GPPractice', 'Gender', 'MissedAppointment']]

# %%
# Encode categorical variables for modeling
model_df = pd.get_dummies(model_df, columns=['Diagnosis', 'GPPractice', 'Gender'], drop_first=True)

# %%
#  Split data into features and target
X = model_df.drop('MissedAppointment', axis=1)
y = model_df['MissedAppointment']

# %%
# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=42, stratify=y)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1998, 9)
# y_train shape: (1998,)
# X_test shape: (2998, 9)
# y_test shape: (2998,)

# %%
#  Standardize features for KNN
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Feature Selection (Variance Threshold)
variance_selector = VarianceThreshold(threshold=0)
X_train_fs = variance_selector.fit_transform(X_train_scaled)
X_test_fs = variance_selector.transform(X_test_scaled)

print(f"{X_train.shape[1]-X_train_fs.shape[1]} features have been removed, {X_train_fs.shape[1]} features remain")
# Out:
# 1 features have been removed, 8 features remain

# %%
# Visualize Retained and Dropped Features
selected_mask = variance_selector.get_support()
features_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Retained': selected_mask.astype(int)
})

plt.figure(figsize=(12, 6))
sns.barplot(x='Feature', y='Retained', data=features_df)
plt.xticks(rotation=90)
plt.title('Retained and Dropped Features after Variance Thresholding')
plt.ylabel('Retained (1 = Yes, 0 = No)')
plt.xlabel('Feature')
plt.show()

# %%
# K-Nearest Neighbors (KNN) Model
knn = KNeighborsClassifier(n_neighbors=5)  # Default K=5
knn.fit(X_train_fs, y_train)
y_pred_knn = knn.predict(X_test_fs)

# Evaluate KNN Model
print("\nKNN Model Performance:")
print(classification_report(y_test, y_pred_knn))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# KNN Model Performance:
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71      1482
#            1       0.72      0.74      0.73      1516
#
#     accuracy                           0.72      2998
#    macro avg       0.72      0.72      0.72      2998
# weighted avg       0.72      0.72      0.72      2998
#
# Confusion Matrix:
# [[1044  438]
#  [ 396 1120]]

# %%
# Decision Tree Model
dt = DecisionTreeClassifier(random_state=42, max_depth=10, min_samples_split=2)  # Default settings
dt.fit(X_train_fs, y_train)
y_pred_dt = dt.predict(X_test_fs)

# Evaluate Decision Tree Model
print("\nDecision Tree Model Performance:")
print(classification_report(y_test, y_pred_dt))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# Decision Tree Model Performance:
#               precision    recall  f1-score   support
#
#            0       0.72      0.67      0.69      1482
#            1       0.70      0.74      0.72      1516
#
#     accuracy                           0.71      2998
#    macro avg       0.71      0.71      0.71      2998
# weighted avg       0.71      0.71      0.71      2998
#
# Confusion Matrix:
# [[ 995  487]
#  [ 389 1127]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. No-Show Rates by Diagnosis
no_show_rate_by_diagnosis = df_clean.groupby('Diagnosis')['MissedAppointment'].mean() * 100

plt.figure(figsize=(12, 6))
sns.barplot(x=no_show_rate_by_diagnosis.index, y=no_show_rate_by_diagnosis.values, palette='viridis')
plt.title('No-Show Rate by Diagnosis', fontsize=16)
plt.ylabel('No-Show Rate (%)')
plt.xlabel('Diagnosis')
plt.xticks(rotation=45)
plt.show()

# 2. Distribution of Appointments Over Time (Optional: Create a date column if available)

# %%
# Ensure dates are sorted (to satisfy rolling window requirements)
df_clean = df_clean.sort_values(by='AppointmentDate')

# Create the rolling average plot
plt.figure(figsize=(12, 6))
sns.lineplot(
    x='AppointmentDate', 
    y='MissedAppointment', 
    data=df_clean.rolling('7D', on='AppointmentDate').mean()
)
plt.title('7-Day Rolling Average of Missed Appointments Over Time', fontsize=16)
plt.ylabel('Missed Appointment Rate')
plt.xlabel('Appointment Date')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27540\2405260741.py:9: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Diagnosis', 'GPPractice', 'Gender', 'Outcome', 'OutcomeClass'], dtype='object')
#   data=df_clean.rolling('7D', on='AppointmentDate').mean()
